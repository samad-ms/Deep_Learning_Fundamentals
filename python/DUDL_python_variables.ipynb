# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Python introduction
# ### LECTURE: Variables
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202212

# %% [markdown]
# # Arithmetic and comments

# %%
4*5
# Out:
# 20

# %%
# a comment!
# 5+4

# %%
4*5
4+5
# Out:
# 9

# %%
print( 4*5 )
print( 4+5 )
# Out:
# 20
# 9

# %% [markdown]
# # Variables

# %%
x = 5
y = 4

x*y
# Out:
# 20

# %%
aLongerVariableName = 4
another_naming_style = 5

# %%
not a variable = 10
# Out:
#   File "<ipython-input-7-6cf07c6d2906>", line 1
#     not a variable = 10
#                  ^
# SyntaxError: invalid syntax

# %%
also?not%a&variable = 10
# Out:
#   File "<ipython-input-8-376479759dd1>", line 1
#     also?not%a&variable = 10
#         ^
# SyntaxError: invalid syntax

# %%
number2use = 5
4somethingElse = 10
# Out:
#   File "<ipython-input-9-40b9c5512d06>", line 2
#     4somethingElse = 10
#                  ^
# SyntaxError: invalid syntax

# %%
stringVariable = 'Hello'
stringVariable
# Out:
# 'Hello'

# %%
stringVariable*2
# Out:
# 'HelloHello'

# %%
firstName = 'mike'
lastName = 'cohen'

firstName + ' ' + lastName
# Out:
# 'mike cohen'

# %% [markdown]
# # Printing mixed variable types

# %%
age = 26

print(firstName + ' is ' + str(age) + ' years old.')
# Out:
# mike is 26 years old.

# %%
# using string interpolation
print('%s is %g years old.' %(firstName,age))
# Out:
# mike is 26 years old.

# %%
# using f-strings
print(f'{firstName} is {age} years old.')
# Out:
# mike is 26 years old.

# %% [markdown]
# # Lists and indexing

# %%
alist = [ 5,4,6,10 ]
alist
# Out:
# [5, 4, 6, 10]

# %%
alist[1]
# Out:
# 4

# %%
alist[0]
# Out:
# 5

# %%
alist[-1]
# Out:
# 10

# %%
print(alist[2])
alist[:2]
# Out:
# 6
# [5, 4]

# %%
alist[2:6]
# Out:
# [6, 10]

# %%
500/60
# Out:
# 8.333333333333334
